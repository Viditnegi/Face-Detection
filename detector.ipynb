# %%
# !pip install labelme opencv-python matplotlib albumentations
# Out:
# ...
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.4 MB 660.6 kB/s eta 0:00:03
#      ---- ----------------------------------- 0.2/1.4 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  1.4/1.4 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached matplotlib-3.8.2-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached albumentations-1.3.1-py3-none-any.whl.metadata (34 kB)
# ...
#      ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#      --------- ------------------------------ 1.8/7.7 MB 59.1 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.2/7.7 MB 40.3 MB/s eta 0:00:01
# ...
